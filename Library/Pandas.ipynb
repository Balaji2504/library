# %%
import pandas as pd

# %%
# Load CSV data into a DataFrame
df = pd.read_csv('Walmart.csv')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
#Select column: 
df['Weekly_Sales']
# Out:
# 0       1643690.90
# 1       1641957.44
# 2       1611968.17
# 3       1409727.59
# 4       1554806.68
#            ...
# 6430     713173.95
# 6431     733455.07
# 6432     734464.36
# 6433     718125.53
# 6434     760281.43
# Name: Weekly_Sales, Length: 6435, dtype: float64

# %%
#Select row:
df.loc[4]
# Out:
# Store                    1
# Date            05-03-2010
# Weekly_Sales    1554806.68
# Holiday_Flag             0
# Temperature           46.5
# Fuel_Price           2.625
# CPI             211.350143
# Unemployment         8.106
# Name: 4, dtype: object

# %%
#Select subset of rows & columns:
df.loc[:, ['Date', 'Weekly_Sales']]
# Out:
#             Date  Weekly_Sales
# 0     05-02-2010    1643690.90
# 1     12-02-2010    1641957.44
# 2     19-02-2010    1611968.17
# 3     26-02-2010    1409727.59
# 4     05-03-2010    1554806.68
# ...          ...           ...
# 6430  28-09-2012     713173.95
# 6431  05-10-2012     733455.07
# 6432  12-10-2012     734464.36
# 6433  19-10-2012     718125.53
# 6434  26-10-2012     760281.43
#
# [6435 rows x 2 columns]

# %%
#Descriptive stats:
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
#Find null values:
df.isnull()
# Out:
#       Store   Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0     False  False         False         False        False       False
# 1     False  False         False         False        False       False
# 2     False  False         False         False        False       False
# 3     False  False         False         False        False       False
# 4     False  False         False         False        False       False
# ...     ...    ...           ...           ...          ...         ...
# 6430  False  False         False         False        False       False
# 6431  False  False         False         False        False       False
# 6432  False  False         False         False        False       False
# 6433  False  False         False         False        False       False
# 6434  False  False         False         False        False       False
#
#         CPI  Unemployment
# 0     False         False
# 1     False         False
# ...

# %%
#Groupby and aggregate:
df.groupby('Weekly_Sales').mean()
# Out:
# 2024-02-11 15:53:04,515 [29084] WARNING  py.warnings:109: [JupyterRequire] C:\Users\jamal\AppData\Local\Temp\ipykernel_29084\978338337.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Weekly_Sales').mean()
#               Store  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# Weekly_Sales
# 209986.25      33.0           0.0        52.82       3.041  126.731333
# 213538.32      33.0           0.0        71.34       3.130  126.436419
# 215359.21      33.0           1.0        51.60       3.428  130.071032
# 219804.85      33.0           1.0        52.91       3.148  127.087677
# 220060.35      33.0           0.0        59.12       3.701  129.845967
# ...             ...           ...          ...         ...         ...
# ...

# %%
# Pivot table:
df.pivot_table(index='Unemployment', columns='Temperature', values='Weekly_Sales', aggfunc='sum')
# Out:
# Temperature   -2.06     5.54     6.23     7.46     9.51     9.55     10.09   \
# Unemployment
# 3.879             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4.077             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4.125             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4.145             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4.156             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...               ...      ...      ...      ...      ...      ...      ...
# 13.975            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14.021            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14.099            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14.180            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14.313            NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
# Plot data:
df['Weekly_Sales'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Sort values:
df.sort_values(by='Weekly_Sales')
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 4619     33  03-12-2010     209986.25             0        52.82       3.041
# 4614     33  29-10-2010     213538.32             0        71.34       3.130
# 4675     33  30-12-2011     215359.21             1        51.60       3.428
# 4623     33  31-12-2010     219804.85             1        52.91       3.148
# 4671     33  02-12-2011     220060.35             0        59.12       3.701
# ...     ...         ...           ...           ...          ...         ...
# 1762     13  24-12-2010    3595903.20             0        34.90       2.846
# 527       4  23-12-2011    3676388.98             0        35.92       3.103
# 1333     10  24-12-2010    3749057.69             0        57.06       3.236
# 2763     20  24-12-2010    3766687.43             0        25.17       3.141
# 1905     14  24-12-2010    3818686.45             0        30.59       3.141
#
#              CPI  Unemployment
# ...

# %%
#Descriptive stats on groupby:
df.groupby('Weekly_Sales').describe()
# Out:
#              Store                                         Holiday_Flag       \
#              count  mean std   min   25%   50%   75%   max        count mean
# Weekly_Sales
# 209986.25      1.0  33.0 NaN  33.0  33.0  33.0  33.0  33.0          1.0  0.0
# 213538.32      1.0  33.0 NaN  33.0  33.0  33.0  33.0  33.0          1.0  0.0
# 215359.21      1.0  33.0 NaN  33.0  33.0  33.0  33.0  33.0          1.0  1.0
# 219804.85      1.0  33.0 NaN  33.0  33.0  33.0  33.0  33.0          1.0  1.0
# 220060.35      1.0  33.0 NaN  33.0  33.0  33.0  33.0  33.0          1.0  0.0
# ...            ...   ...  ..   ...   ...   ...   ...   ...          ...  ...
# 3595903.20     1.0  13.0 NaN  13.0  13.0  13.0  13.0  13.0          1.0  0.0
# 3676388.98     1.0   4.0 NaN   4.0   4.0   4.0   4.0   4.0          1.0  0.0
# 3749057.69     1.0  10.0 NaN  10.0  10.0  10.0  10.0  10.0          1.0  0.0
# 3766687.43     1.0  20.0 NaN  20.0  20.0  20.0  20.0  20.0          1.0  0.0
# ...

# %%
# Rolling/expanding statistics:
df['Weekly_Sales'].rolling(window=20).mean()
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 6430    762478.2255
# 6431    759108.8650
# 6432    754945.0245
# 6433    748994.0695
# 6434    747251.4910
# Name: Weekly_Sales, Length: 6435, dtype: float64

# %%
# Drop rows with missing values:
df.dropna()

# %%
#Fill missing values:
df.fillna(value)

# %%
# Apply function to column:
df['Weekly_Sales'].apply(function)

# %%
# Filter rows based on condition:
new_df = df[df['Weekly_Sales'] > value]

# %%
# Pivot table percentage of total:
df.pivot_table(index='Column1', values='Column2', aggfunc=lambda x: x/x.sum()*100)

# %%
# Data visualization:
df.plot(kind='scatter', x='x_col', y='y_col')
